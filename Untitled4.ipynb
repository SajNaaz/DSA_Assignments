# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/content'

# %%
dt=pd.read_csv('/content/cars_data (3).csv')

# %% [markdown]
# **1. Read the dataset to the python environment**

# %%
dt
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %%
r

# %% [markdown]
# There are 10000 rows and 20 colummns whichgives the data about cars models,car gender, buyer gender, country, sales price etc

# %% [markdown]
# **2. Check for the null values present in the dataset**

# %%
dt.isna(
    
)
# Out:
#        Make  Model  Nickname  ...  5-yr Depreciation  Top Speed  0-60 Time
# 0     False  False     False  ...              False      False      False
# 1     False  False     False  ...              False      False      False
# 2     False  False     False  ...              False      False      False
# 3     False  False     False  ...              False      False      False
# 4     False  False     False  ...              False      False      False
# ...     ...    ...       ...  ...                ...        ...        ...
# 9995  False  False     False  ...              False      False      False
# 9996  False  False     False  ...              False      False      False
# 9997  False  False     False  ...              False      False      False
# 9998  False  False     False  ...              False      False      False
# 9999  False  False     False  ...              False      False      False
#
# [10000 rows x 20 columns]

# %%
dt.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# We could infer that there is no missing values are present in the given data set.

# %% [markdown]
# **3. Plot a bar graph of male vs female buyers participated in the sales**

# %% [markdown]
# Now let's check for the number of males and females participated in the sales event.

# %%
male_numbr=dt[['Buyer Gender']].value_counts()['Male']
female_numbr=dt[['Buyer Gender']].value_counts()['Female']
print('The number of male and female s participated in event are',male_numbr ,female_numbr)
# Out:
# The number of male and female s participated in event are Buyer Gender
# Male            4948
# dtype: int64 Buyer Gender
# Female          5052
# dtype: int64

# %% [markdown]
# So 4948 males and 5052 females were participated.

# %%
plt.figure(figsize=(15,8))
plot=plt.subplot(1,1,1)
male_numbr=dt[['Buyer Gender']].value_counts()['Male']
female_numbr=dt[['Buyer Gender']].value_counts()['Female']
plt.bar(dt['Buyer Gender']=='Male', male_numbr, width=0.5, align='center', label='Male')
plt.bar(dt['Buyer Gender']=='Female', female_numbr,width=0.4, align='edge', label='Female')
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(labels)
plt.xticks([])
plt.grid(linestyle='--')

plt.xlabel('Buyer Gender')
plt.ylabel('Sales Price')
plt.title('Bar graph of male vs female buyers participated in the sales')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **4. Find the top 5 cars based on their sales price.**

# %% [markdown]
# Let's sort out the top 5 cars in descending order and then seperate it out in a compressed table.

# %%
top_cars=dt.sort_values('Sale Price', ascending=False).head()
top_cars
# Out:
#             Make      Model   Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 5984  Volkswagen  Jetta III    Rachael  ...              0.06     204.9       12.6
# 1270        Audi         A6      Thorn  ...              0.16     171.3       13.0
# 3460       Lexus         LX      Aldin  ...              0.12     193.7        4.5
# 9032       Mazda       MX-6  Sylvester  ...              0.15     232.0        3.9
# 302        Lexus         ES       Brig  ...              0.21     228.1        4.7
#
# [5 rows x 20 columns]

# %% [markdown]
# Compressed table consists of model and sales price value for the first 5 cars

# %%
top_cars = top_cars[['Make','Model','Sale Price']]
top_cars.head()
# Out:
#             Make      Model  Sale Price
# 5984  Volkswagen  Jetta III    99997.65
# 1270        Audi         A6    99991.91
# 3460       Lexus         LX    99983.38
# 9032       Mazda       MX-6    99978.17
# 302        Lexus         ES    99973.44

# %% [markdown]
# So the top 5 cars having the best sale price are Volkswagen, Audi,Lexus,Mazda and Lexus ES model.

# %% [markdown]
# **5. Find the least 5 cars based on their Resell price.**

# %% [markdown]
# In a similiar way let's find out the least resell price for the cars by sorting out and compressing in a table consists of make and resell price.

# %%
least_resell_price_cars=dt.sort_values('Resell Price', ascending=True).head()
least_resell_price_cars
# Out:
#             Make        Model Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 2446   Chevrolet         1500  Corenda  ...              0.25     239.6       11.2
# 4933         GMC  Savana 1500     Lark  ...              0.01     158.7        9.0
# 566       Jaguar           XF   Payton  ...              0.19     249.3        6.9
# 2538  Mitsubishi       3000GT     Thia  ...              0.14     222.0       10.3
# 5869    Infiniti          G37    Sonny  ...              0.04     131.6       12.3
#
# [5 rows x 20 columns]

# %%
least_resell_price_cars = least_resell_price_cars [['Make','Model','Sale Price']]
least_resell_price_cars.head()
# Out:
#             Make        Model  Sale Price
# 2446   Chevrolet         1500    49909.44
# 4933         GMC  Savana 1500    80084.82
# 566       Jaguar           XF    24124.99
# 2538  Mitsubishi       3000GT    88195.95
# 5869    Infiniti          G37    77791.65

# %% [markdown]
# So Chevrolet, GMC, jaguar, Mitsubhishi and Infinity have the least Resell values rather than the others.
